# %%
import pandas as pd

# %%
pd.read_json("../data/118-processed-bios.json").head(3).T  # .to_markdown()
# Out:
#                                                                           8   \
# givenName                                                            Burgess
# familyName                                                             Owens
# congresses                                                        [117, 118]
# profileText                a Representative from Utah; born in Columbus, ...
# jobPositions               [{'job': {'name': 'Representative', 'jobType':...
# party                                                                      R
# state                                                                     UT
# senator                                                                False
# congressLabels                                          Burgess Owens (R-UT)
# communityCollege                                                       False
# eliteCollege                                                           False
# ...
